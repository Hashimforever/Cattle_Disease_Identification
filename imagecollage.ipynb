# %%
from PIL import Image
import os

# Specify the desired size for the resized images
image_size = (200, 200)

# Directory containing the input images
input_directory = 'E:/jupyter notebook/HeatMap/last/'

# Create a list to store the resized images
resized_images = []

# Iterate over the input images
for i in range(1, 21):
    # Load the image
    image_path = os.path.join(input_directory, f'image{i}.JPG')
    image = Image.open(image_path)
    
    # Resize the image
    resized_image = image.resize(image_size)
    resized_images.append(resized_image)

# Calculate the size of the final collage image
collage_width = image_size[0] * 4
collage_height = image_size[1] * 5

# Create a new blank image for the collage
collage = Image.new('RGB', (collage_width, collage_height))

# Iterate over the resized images and paste them onto the collage
for i, image in enumerate(resized_images):
    row = i // 5  # Calculate the row index
    col = i % 5   # Calculate the column index
    x = col * image_size[0]  # Calculate the x coordinate
    y = row * image_size[1]  # Calculate the y coordinate
    collage.paste(image, (x, y))

# Display the collage
collage.show()

# %%
from PIL import Image
import os

# Specify the desired size for the resized images
image_size = (200, 200)

# Directory containing the input images
input_directory = 'E:/jupyter notebook/HeatMap/'

# Create a list to store the resized images
resized_images = []

# Iterate over the input images
for i in range(1, 21):
    # Load the image
    image_path = os.path.join(input_directory, f'image{i}.jpg')
    image = Image.open(image_path)
    
    # Resize the image
    resized_image = image.resize(image_size)
    resized_images.append(resized_image)

# Calculate the size of the final collage image
collage_width = image_size[0]
collage_height = image_size[1] * 20

# Create a new blank image for the collage
collage = Image.new('RGB', (collage_width, collage_height))

# Iterate over the resized images and paste them onto the collage
for i, image in enumerate(resized_images):
    x = 0  # X-coordinate for the first column
    y = i * image_size[1]  # Calculate the y coordinate
    collage.paste(image, (x, y))

# Display the collage
collage.show()

# %%
from PIL import Image
import math

# List of input image paths
image_paths = [
    "E:/jupyter notebook/HeatMap/last/image1.JPG",
    "E:/jupyter notebook/HeatMap/last/image2.JPG",
    "E:/jupyter notebook/HeatMap/last/image3.JPG",
    "E:/jupyter notebook/HeatMap/last/image4.JPG",
    "E:/jupyter notebook/HeatMap/last/image5.JPG",
    "E:/jupyter notebook/HeatMap/last/image6.JPG",
    "E:/jupyter notebook/HeatMap/last/image7.JPG",
    "E:/jupyter notebook/HeatMap/last/image8.JPG",
    "E:/jupyter notebook/HeatMap/last/image9.JPG",
    "E:/jupyter notebook/HeatMap/last/image10.JPG",
    "E:/jupyter notebook/HeatMap/last/image11.JPG",
    "E:/jupyter notebook/HeatMap/last/image12.JPG",
    "E:/jupyter notebook/HeatMap/last/image13.JPG",
    "E:/jupyter notebook/HeatMap/last/image14.JPG",
    "E:/jupyter notebook/HeatMap/last/image15.JPG",
    "E:/jupyter notebook/HeatMap/last/image16.JPG",
    "E:/jupyter notebook/HeatMap/last/image17.JPG",
    "E:/jupyter notebook/HeatMap/last/image18.JPG",
    "E:/jupyter notebook/HeatMap/last/image19.JPG",
    "E:/jupyter notebook/HeatMap/last/image20.JPG",
    # Add the paths of the remaining 18 images here
]

# Desired width and height for the images in the collage
target_width = 300
target_height = 300

# Calculate the number of rows and columns for the collage
num_rows = 5
num_cols = 4

# Create a blank canvas for the collage
collage_width = target_width * num_cols
collage_height = target_height * num_rows
collage = Image.new("RGB", (collage_width, collage_height))

# Iterate over the image paths and resize each image
for i, image_path in enumerate(image_paths):
    # Open the image
    image = Image.open(image_path)

    # Resize the image
    image = image.resize((target_width, target_height))

    # Calculate the coordinates for placing the resized image in the collage
    row = math.floor(i / num_cols)
    col = i % num_cols
    x = col * target_width
    y = row * target_height

    # Paste the resized image onto the collage
    collage.paste(image, (x, y))

# Display the collage
collage.show()
